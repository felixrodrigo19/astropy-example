# %%
pip install dust_extinction
# Out:
# Collecting dust_extinction
#   Downloading dust_extinction-1.0.tar.gz (439 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from dust_extinction) (1.6.2)
# Requirement already satisfied: astropy in c:\programdata\anaconda3\lib\site-packages (from dust_extinction) (4.2.1)
# Requirement already satisfied: pyerfa in c:\programdata\anaconda3\lib\site-packages (from astropy->dust_extinction) (1.7.3)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from astropy->dust_extinction) (1.20.1)
# Building wheels for collected packages: dust-extinction
#   Building wheel for dust-extinction (PEP 517): started
#   Building wheel for dust-extinction (PEP 517): finished with status 'done'
# Note: you may need to restart the kernel to use updated packages.
#   Created wheel for dust-extinction: filename=dust_extinction-1.0-py3-none-any.whl size=424676 sha256=e5f9705e0bcb58c7d53e169bec1edfedd171956bfc694d78e90bf804728d59fe
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\8f\b9\5a\14a9e000520c17be8def4aff41296ff083febd5eb43ace4535
# Successfully built dust-extinction
# Installing collected packages: dust-extinction
# Successfully installed dust-extinction-1.0

# %%
pip install synphot
# Out:
# Collecting synphot
#   Downloading synphot-1.1.1-cp38-cp38-win_amd64.whl (900 kB)
# Requirement already satisfied: numpy>=1.16 in c:\programdata\anaconda3\lib\site-packages (from synphot) (1.20.1)
# Requirement already satisfied: astropy>=3.2 in c:\programdata\anaconda3\lib\site-packages (from synphot) (4.2.1)
# Requirement already satisfied: scipy>=1.1 in c:\programdata\anaconda3\lib\site-packages (from synphot) (1.6.2)
# Requirement already satisfied: pyerfa in c:\programdata\anaconda3\lib\site-packages (from astropy>=3.2->synphot) (1.7.3)
# Installing collected packages: synphot
# Successfully installed synphot-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install astroquery
# Out:
# Collecting astroquery
#   Downloading astroquery-0.4.4-py3-none-any.whl (4.5 MB)
# Requirement already satisfied: numpy>=1.16 in c:\programdata\anaconda3\lib\site-packages (from astroquery) (1.20.1)
# Collecting pyvo>=1.1
#   Downloading pyvo-1.1-py3-none-any.whl (802 kB)
# Requirement already satisfied: requests>=2.4.3 in c:\programdata\anaconda3\lib\site-packages (from astroquery) (2.25.1)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in c:\programdata\anaconda3\lib\site-packages (from astroquery) (4.9.3)
# Requirement already satisfied: html5lib>=0.999 in c:\programdata\anaconda3\lib\site-packages (from astroquery) (1.1)
# Requirement already satisfied: astropy>=4.0 in c:\programdata\anaconda3\lib\site-packages (from astroquery) (4.2.1)
# Requirement already satisfied: keyring>=4.0 in c:\programdata\anaconda3\lib\site-packages (from astroquery) (22.3.0)
# Requirement already satisfied: pyerfa in c:\programdata\anaconda3\lib\site-packages (from astropy>=4.0->astroquery) (1.7.3)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.3.2->astroquery) (2.2.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib>=0.999->astroquery) (1.15.0)
# Requirement already satisfied: pywin32-ctypes!=0.1.0,!=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from keyring>=4.0->astroquery) (0.2.0)
# Collecting mimeparse
#   Downloading mimeparse-0.1.3.tar.gz (4.4 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.3->astroquery) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.3->astroquery) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.3->astroquery) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.4.3->astroquery) (2.10)
# Building wheels for collected packages: mimeparse
#   Building wheel for mimeparse (setup.py): started
#   Building wheel for mimeparse (setup.py): finished with status 'done'
#   Created wheel for mimeparse: filename=mimeparse-0.1.3-py3-none-any.whl size=3863 sha256=a56e92a220c1fa74488722d1861326a72c15bcf44f98b1139e17cb52d2a5c4fd
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\10\4a\42\2f6bad162811fe51b5e3f250cb31c88e0d362b23e873380815
# Successfully built mimeparse
# Installing collected packages: mimeparse, pyvo, astroquery
# Successfully installed astroquery-0.4.4 mimeparse-0.1.3 pyvo-1.1

# %%
import pathlib

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import astropy.units as u
from astropy.table import Table
from dust_extinction.parameter_averages import CCM89, F99
from synphot import units, config
from synphot import SourceSpectrum, SpectralElement, Observation, ExtinctionModel1D
from synphot.models import BlackBodyNorm1D
from synphot.spectrum import BaseUnitlessSpectrum
from synphot.reddening import ExtinctionCurve
from astroquery.simbad import Simbad
from astroquery.mast import Observations
import astropy.visualization

# %%
wav = np.arange(0.1, 3.0, 0.001)*u.micron

for model in [CCM89, F99]:
    for R in (2.0, 3.0, 4.0):
        ext = model(Rv = R)
        plt.plot(1/wav, ext(wav), label=model.name+' R='+str(R))

plt.xlabel('$\lambda^{-1}$ ($\mu$m$^{-1}$)')
plt.ylabel('A($\lambda$) / A(V)')
plt.legend(loc='best')
plt.title('Some Extinction Laws')
plt.show()
